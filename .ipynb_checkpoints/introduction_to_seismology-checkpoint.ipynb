# %% [markdown]
# #Introduction to seismology
#
#
# * ##<span style="color:orange"> Earthquakes and faulting (& statistics)
#     * A recap of faults from the perspective of geology and seismology
# * ##<span style="color:blue"> Elastic waves (waveforms & numerical modelling)
#     * Obspy for (delayed) data analysis
#     * P and S waves (Velocity or displacement)
#     * Rays, and why do waves reflect anyway?
# * ##<span style="color:green"> Measuring seismic waves and correction
#     * What are we measuring (and why is diffucult?)
#     * What is a seismometer?

# %% [markdown]
# ##By the end of this lecture you should have some idea of:
#
# * How earthquakes are measured - size and shape
# * How easy it is to access data on natural earthquakes
# * Elastic wave generation and propagation (both P and S waves)
# * How computers are used to simulate wave propagation (and why?)
# * What a seismometer is
# * How easy it is to access global digital waveform data

# %% [markdown]
# ##But first a tiny bit about Python...
#
#
# A programming language is a constructed language designed to communicate instructions to a computer. This is a  powerful way to work with data and model physics.
#
# From the beginners standpoint, you can simply treat a language like Python as a toolbox of functions for accessing and working with data.
#
# In this lecture I'm using the Python package called Obspy, a framework for processing seismological data.
#
# The slides I'm showing are executing small snippets of code on my computer, and the output is returned to my browser as HTML. It's a little convoluted, but the advantage is that you can go and "run" this lecture by downloading it here:
#
# https://github.com/dansand/seismic

# %%
# %pylab inline

import numpy as np
from mpl_toolkits.basemap import Basemap
import obspy
from obspy.imaging.beachball import beach
import os
from obspy.clients.fdsn import Client
from obspy import UTCDateTime
from matplotlib import cm, rcParams
from IPython.display import YouTubeVideo
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['shape', 'plt', 'mpl']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ##<span style="color:orange">Earthquakes and faulting
#
# * geological faults provide fairly convincing evidence of the brittle and discreet nature of deformation in the earth's lithosphere.
#
# * Seismology has traditionally focussed on measuring and interpreting the elastic waves that sudden slips produce.
#
#
# <img src="./images/darfield_rupture.jpg " alt="Caption to image" align="left" style="width: 400px;"/>

# %% [markdown]
# ##<span style="color:orange">Earthquakes and faulting
#
# * As a geophysical discipline seismology has given unprecedented insight into the nature of the solid earth:
#  * sources of seismic waves (earthquakes) are themselves an indelible signal of Tectonic nature of the lithosphere
#  * waves are sensitive to boundaries betweeen layers (cf. gravity) & mineralogic/lithologic anisitropy
#
#
# <img src="./images/seismicity_glob_neic.png " alt="Caption to image" align="left" style="width: 500px;"/>

# %% [markdown]
# ##<span style="color:orange">Earthquakes and faulting
#
# * A number of global earthquake databases exist,
# * Here Obspy is used to pull an event from IRIS (Incorporated Research Institutions for Seismology)

# %%
client = Client("IRIS")
start = UTCDateTime("2014-09-01T15:10:00")
end= UTCDateTime.now()
cat = client.get_events(starttime=start, endtime=end,latitude=-38.1, longitude=144.00,minradius=0., maxradius=5.)
inv = client.get_stations(longitude=144.00, latitude=-38.1, maxradius=2, level="channel")

# %%
evplot = cat.plot(projection="local", resolution='i', continent_fill_color="pink")

# %%
#plot inventory, reusing mpl Figure
inv.plot(fig=evplot)

# %% [markdown]
# ##<span style="color:orange">Earthquakes and faulting
#
# As in all physics, seismology employs approximations; earthquakes are commonly approximated as infinitesimally localized events in space, i.e. at the hypocenter, which begin at an instant, the origin time.
#
#
# <img src="./images/hypocenter.jpeg " alt="Caption to image" align="left" style="width: 400px;"/>

# %% [markdown]
# ##<span style="color:orange">Earthquakes and faulting
#
# * While still keeping with the point source approximation,  we are often interested in characterizing the the geometry of the earthquake source
#
# * The following script reads moment tensor information from the IRIS database: http://ds.iris.edu/spud/momenttensor

# %%
#%pylab inline
fig = %run ./scripts/chile_plot.py
fig;  #silence the display hook with a semicolon, prevent fig displaying twice
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/ESRI_Imagery_World_2D/MapServer/export?bbox=-77.0,-37.0,-67.0,-27.0&bboxSR=4326&imageSR=4326&size=1500,1500&dpi=96&format=png32&f=image

# %% [markdown]
# <img src="./images/Chile1709_PacificView.png " alt="Caption to image" style="width: 900px;"/>

# %% [markdown]
# ##<span style="color:orange">Earthquakes and faulting
#
# * The Beachball plot is a way of representing a tensor (called the moment tensor);
# * The beachball is simply a stereonet, the lines on the beachball represent planes in 3D => fault plane (s)
#
# <img src="./images/focal_mechanism.jpeg " alt="Caption to image" align="left" style="width: 400px;"/>

# %% [markdown]
# ##<span style="color:orange">Earthquakes and faulting

# %%
YouTubeVideo("HL3KGK5eqaw")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/HL3KGK5eqaw"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #<span style="color:orange">Earthquakes and faulting

# %%
client = Client("USGS")
start = UTCDateTime("2015-04-25")
end= UTCDateTime("2015-05-25")
cat2 = client.get_events(starttime=start, endtime=end,latitude=24.147, longitude=84.708,minradius=0., maxradius=6.1)
lats = []
lons = []
labels = []
mags = []
times = []
for event in cat2:
    origin = event.preferred_origin() or event.origins[0]
    lats.append(origin.latitude)
    lons.append(origin.longitude)
    times.append(origin.time)
    magnitude = event.preferred_magnitude() or event.magnitudes[0]
    mag = magnitude.mag
    mags.append(mag)

# %%
fig = plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
juldays = [d.julday for d in times]
seqnum = range(len(lats))
seqnum.reverse()
plt.scatter(juldays, seqnum)

ax = plt.subplot(1, 2, 2)
n, bins, patches = ax.hist(mags, 10, normed=False, histtype='stepfilled', cumulative=-1, log=True)
plt.setp(patches, 'facecolor', 'w', 'alpha', 1.)
#ax.set_ylim(1,1.2)
fig.show()

# %% [markdown]
# #<span style="color:orange">Earthquakes and faulting
#
# * Although famous for the Richter scale, Richter made a more important observationEncapsulated in the Gutenberg-Richter Law:
#
# $$log N(M) = a - bM $$
#
# * The Omori afteshock decay law is:
#
# $$N(t) = \frac {k}{c + t}$$

# %% [markdown]
# #<span style="color:orange">Interlude: Inverse Problems
#
# * At this point you might also wonder how earthquakes are located, or moment tensors calculated
# * In an inverse problem, once usually wants to minimise the misfit $\chi$ the between observations $\bf{d}$ and the realisation of a physical model $F(\bf{m})$ subject to a set of model paramters $\bf{m}$
#
# $$ \chi  = F(\bf{m}) - \bf{d}$$
# * Seismology is full of inverse problems, and geophysics problems have inspired a number of advances in general inverse theory
#
# http://www.ipgp.fr/~tarantola/Files/Professional/Books/InverseProblemTheory.pdf

# %% [markdown]
# ##<span style="color:blue"> Elastic waves
#
# For small elastic deformations the relation between the deformation and the resulting stress can be linearised; this linearisation is expressed by Hooke’s law:
#
# $$ F = k\triangle x$$
#
# <img src="./images/hookes.jpeg " alt="Caption to image" align="left" style="width: 250px;"/>
#
# When this material model is combined with a mathematical expression for the convservation of momentum, a wave equation results.

# %% [markdown]
# ##<span style="color:blue"> Elastic waves
#
#
# * Elastodynamic waves are vector waves, with no restriction on the polarisation. Because there are three spatial dimensions, elastodynamic waves can have three different polarisations.
#
# * Waves in a bulk solid can be transverse as well as longitudinal, for a total of three polarization components.
#
# * Longitudinal waves propagate at a higher velocity than do the transverse waves. The nomenclature “P wave” and “S waves” historically denotes the first arriving (primary) and later arriving (secondary) body waves.
#
# * Shear wave anisotropy is a major constraint on deep mantle flow (indicative of dislocation creep in Olivine)

# %% [markdown]
# <img src="images/TransverseWave.gif" height="45%" width="45%">
# <img src="images/compressionwave.gif" height="45%" width="45%">

# %%
ev = cat[0]
ot = ev.origins[0]['time']
st = client.get_waveforms("AU", "TOO", "", "*", ot - 0.2 * 60, ot + 1. * 60, attach_response=True)
st.remove_response(output="VEL")
# Out:
# 3 Trace(s) in Stream:
# AU.TOO..BHE | 2014-12-03T19:04:58.019500Z - 2014-12-03T19:06:09.994500Z | 40.0 Hz, 2880 samples
# AU.TOO..BHN | 2014-12-03T19:04:58.019500Z - 2014-12-03T19:06:09.994500Z | 40.0 Hz, 2880 samples
# AU.TOO..BHZ | 2014-12-03T19:04:58.019500Z - 2014-12-03T19:06:09.994500Z | 40.0 Hz, 2880 samples

# %%
st.plot()

# %%
#P and S waves arrivals

st2 = st.copy()
tr = st2[1]
tr.trim(ot+8,ot+27).plot()

# %% [markdown]
# ##<span style="color:blue"> Elastic waves (ray theory)
#
# Ray theory originally emerged from optics where it was used to understand the propagation of light even before more fundamental equations for light propagation (Maxwell’s equation) were known.
#
# Solving the elastic wave equation requires significant computational effort. Ray theory is an alternative approach in which a point on the wavefront is tracked rather than the complete wavefield.
#
# By applying Fresnel relations (reflection and transmission) and Snell’s law at each interface that a ray passes through, it is possible to determine the path of the ray through a system if only simple reflection and refraction are assumed.

# %%
from IPython.html.widgets import interact
from obspy.taup import TauPyModel

m = TauPyModel("ak135")

def plot_raypaths(distance, depth, wavetype):
    try:
        plt.close()
    except:
        pass
    if wavetype == "all":
        phases = ["ttall"]
    elif wavetype == "diff":
        phases = ["Pdiff", "pPdiff"]
    m.get_ray_paths(distance_in_degree=distance,
                    source_depth_in_km=depth,
                    phase_list=phases).plot();
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
interact(plot_raypaths, distance=[0, 180],
         depth=[0, 700], wavetype=["all", "diff"])

# %%
m.get_ray_paths(10, 5, phase_list=["P"]).plot(plot_type="cartesian", plot_all=True)

# %% [markdown]
# ##<span style="color:blue"> Elastic waves
#
# ###Shadow zones
#
# The primary seismic waves are refracted by the liquid outer core of the Earth and are not detected between 104° and 140°

# %%
fig = %run ./scripts/taupy_shadow_zone.py
fig;  #silence the display hook with a semicolon, prevent fig displaying twice

# %% [markdown]
# ##<span style="color:blue"> Elastic waves
#
# ###Numerical models of wave propagation

# %%
#%pylab inline
fig1 = %run ./scripts/wavefield_animation.py
#fig1;  #silence the display hook with a semicolon, prevent fig displaying twice
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# A more sophisticated model...
#
# ![Alt text](./images/axisem.png)

# %%
YouTubeVideo("Tx-u_HULFnY")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/Tx-u_HULFnY"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## <span style="color:green"> Measuring seismic waves and correction
#
# ###Seismometer and digitizer
#
# * Seismographs operate on the principle of resistance to acceleration (like all mass)
# * The force that accelerates the mass is "channelled" through fixed components (e.g spring & dashpot)
# * We can only ever measure the relative displacment between the mass and the exterior
# * But we can use the relative motion to recover the ground acceleration, velocity, displacement.

# %% [markdown]
# ## <span style="color:green"> Measuring seismic waves and correction
#
# <img src="./images/seismometer.png "align="left"  alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# ## <span style="color:green"> Measuring seismic waves and correction
#
# * The motion of the seismometer mass as a function of the ground displacement is given through a differential equation resulting from the equilibrium of forces.
#
# * The forces are:
#
# $f_i = - m\ddot u_m(t)$
#
# $f_{sp} = -kx_r(t)$
#
# $f_f = -D\dot x_m(t)$
#
# * We end up with a differential equation for the damped harmonic oscillator:
#
# $$-\ddot x_r(t) - 2\epsilon \dot x_r(t) - \omega_0^2 x(t) = \ddot u_g(t)$$

# %% [markdown]
# * for slow movements the acceleration and velocity becomes negligible, the seismometer records ground acceleration
#
# * for fast movements the acceleration of the mass dominates and the seismometer records ground displacement
#
# * in general, $u_g \neq x_r$; but instrument correction will restore the true ground motion

# %% [markdown]
# ## <span style="color:green"> Measuring seismic waves and correction
#
# * Converting raw seismometer recordings to physical units (aka instrument correction)
# * we need to combine the raw waveform data of the recording system (seismometer, digitizer) with the metadata on its amplitude and phase response (the instrument response)
# * these information are kept separate for various practical and technical reasons (space in storage and streaming, correcting of errors made in the metadata, ...)

# %%
from obspy import read, read_inventory

st = read("/path/to/IU_ULN_00_LH1_2015-07-18T02.mseed")
tr = st[0]
inv = read_inventory("/path/to/IU_ULN_00_LH1.xml")
tr.attach_response(inv)

pre_filt = [0.001, 0.005, 10, 20]

# %%
tr.remove_response(pre_filt=pre_filt, output="DISP",
                   water_level=60, plot=True)
# Out:
# IU.ULN.00.LH1 | 2015-07-18T02:27:33.069538Z - 2015-07-18T05:27:32.069538Z | 1.0 Hz, 10800 samples

# %%
YouTubeVideo("o7BfwJommEY")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/o7BfwJommEY"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ##Links to data
#
# - pretty much everything used in this lecture comes from IRIS
#
# http://www.iris.edu/hq/
#
# - University of Melbourne/AGOS data:
#
# http://meiproc.earthsci.unimelb.edu.au/eqserver/
#
# ##People and projects areas
#
#
# * Gary Gibson (Seismic risk and observation seismology)
# * Tim Rawling & Dave Belton (observation seismology, seismic risk, data management)
# * Mark Quigley (Neptectonics and Paleoseismology)
# * Mike Sandiford (seismo tectonics, surface process feedbacks)
# * Louis Moresi (geodynamics models, reciever functions, ambient noise tomography)
# * Peter Rayner (inverse problems)
# * myself (earthquake location, full waveform inversion)

# %% [markdown]
# ##Links to software
#
# Anaconda python: http://continuum.io/downloads
#
# Obspy: http://docs.obspy.org/
#
# this notebook: https://github.com/dansand/seismic
#
#
# ##Links to software training (e.g. Python)
#
# http://melbourne.resbaz.edu.au/
#
# https://software-carpentry.org/lessons.html
#
# Or, come to HackyHour...Thursdays 3 - 4pm, Tsubu Bar
